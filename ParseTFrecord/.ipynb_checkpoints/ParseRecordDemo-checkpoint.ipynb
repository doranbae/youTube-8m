# %% [markdown]
# Parse the tf records to JSON file
#
# ** usage of parsing script **
# Arguments:
#
# 1. Feature type:
# To parse video-level features, use "video" argument.
# To parse frame-level features, use "frame" argument.
# 2. Input path
# 3. Output path
#
#
# ** Remember to quote the input path arguments **
# ** "train-labels-histogram.csv" needs to be in the same folder as "yt8m_parse.py" in order to get the label names **

# %%
# !python yt8m_parse.py video "train4u.tfrecord" \
"parsedjsonExample.json"
# Out:
# Finished extracting.

# %%
# check the parsed files
import pandas as pd
parsed=pd.read_json("parsedjsonExample.json")
parsed.head()
# Out:
#                                             features      labels          vid
# 0  [0.06323999911546707, 0.35495999455451965, -0....  Video game  4uNte5fghso
# 1  [0.24004000425338745, -0.6879100203514099, -0....  Video game  4uX67B9emkk
# 2  [0.5066400170326233, 1.0234999656677246, -0.70...   Gardening  4u5CSZCWyZA
# 3  [-0.20882999897003174, 0.777400016784668, -0.2...         Pen          4u!
# 4  [1.1822400093078613, 0.40184998512268066, -0.2...     Dashcam  4uc9uzwtGNo

# %%
import json 
parseExample=json.load(open("parsedjsonExample.json", 'r'))
parseExample[0]
# Out:
# {u'features': u'[0.06323999911546707, 0.35495999455451965, -0.2762799859046936, 0.6855300068855286, -0.6255900263786316, 0.06797999888658524, -0.6175900101661682, 0.20104999840259552, -0.5864199995994568, 0.5162500143051147, 0.08429999649524689, -0.17890000343322754, 0.0879800021648407, 0.18030999600887299, 0.32927998900413513, -0.2810100018978119, 0.24895000457763672, -0.3641799986362457, -0.12077999860048294, -0.5975800156593323, 0.0009200000204145908, -0.2432200014591217, 0.12409000098705292, 0.5330899953842163, -0.31891000270843506, 0.5339300036430359, -0.6500099897384644, 0.13051000237464905, -0.3383899927139282, 0.6747999787330627, -0.08940999954938889, -0.07320000231266022, 0.28852999210357666, 0.5318300127983093, 0.4785600006580353, 0.41402000188827515, -0.13741999864578247, 0.2502099871635437, -0.2690100073814392, -0.048670001327991486, -0.08677999675273895, -0.8995199799537659, -0.04413999989628792, 0.2542099952697754, 0.25863000750541687, -0.1507900059223175, -0.0430900007
# ...
