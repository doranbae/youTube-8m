# %%
import pafy
import json
import requests
import re
import numpy as np
import pandas as pd
import csv 
import urllib

import sys
reload(sys)
sys.setdefaultencoding('utf-8')

pafy.set_api_key("AIzaSyCnrbLP8V3zdMwG9kaTaCmeq49nNqyEpZ8")

# %% [markdown]
# ### Get video ID by Google Knowledge Entities

# %%
# Download the vocabulary list from the site.
urllib.URLopener().retrieve("http://research.google.com/youtube8m/csv/train-labels-histogram.csv" , "knowledgeGraphList.csv")
# Out:
# ('knowledgeGraphList.csv', <httplib.HTTPMessage instance at 0x1228e4680>)

# %%
# Save only the GraphID with its corresponding LabelName
df1 = pd.read_csv('knowledgeGraphList.csv')
KgraphID = df1[['KnowledgeGraphID','LabelName','FirstVertical','SecondVertical','ThirdVertical']]
KgraphID.head(n=5)

# Remove '/m/' from GraphID column
#graphID.replace({'/m/' : ''}, regex = True)
#graphID.apply(lambda x: x.str.replace('/m/',''))
series = KgraphID["KnowledgeGraphID"]
series = series.str.replace('/m/','')
#series

# %% [markdown]
# ##### For the Test run

# %%
series_sample = series[4796:4799]
series_sample
# Out:
# 4796    02w37j
# 4797    055rn5
# 4798    023qc5
# Name: KnowledgeGraphID, dtype: object

# %%
from itertools import repeat

KgraphIDList_sample = series_sample
total_list = []
total_k = []
empty_frames = []

for k in KgraphIDList_sample:
    call_kg_page = requests.get("http://storage.googleapis.com/www.yt8m.org/csv/j/%s.js" % k)
    to_string = str(call_kg_page.text)
    n = to_string.count(";")
    to_list = to_string.split(";", n-1)
    list_filter = [list_filter for list_filter in to_list if len(list_filter) == 11]
    total_list.append(list_filter)
    total_list_unnested = sum(total_list, [])
    total_k = list(repeat(k,len(total_list_unnested)))
    #print(total_list_unnested[:10])
    #print(total_k[:10])
    subdt1 = pd.DataFrame({
            'vID': total_list_unnested,
            'key': total_k})
    empty_frames.append(subdt1)

result = pd.concat(empty_frames)
#print(result.head(n=5))
#print(result.tail(n=5))
#print(result.shape)
print("Done")

# %%
print(result.head(n=20))

# %%
resultList = result["vID"].tolist()
resultList[:10]
len(resultList)
# Out:
# 684

# %%
#videoo = ['JoH-PBzb4ks', 'XM3q5l4bhL4', 'rmDzaw-FOHM', 'soOX-09dsCw', 'Rh7vXE8RfVg'] #test run
videoo = resultList
def get_video_info():
    #video = vidList # Right now, some video IDs seems to not work in Korea. 
    video = videoo
    
    vid_ID = []
    title = []
    thumbnail = []
    #print video
    for v in video:
        vid_url = "https://www.youtube.com/watch?v=%s" % v
        vid = pafy.new(vid_url)
        #print(vid.title)
        title.append(vid.title)
        thumbnail.append(vid.thumb)
        vid_ID.append(v)
    g = pd.DataFrame(
        {'ktree' : '07yv9',
        'ID': vid_ID,
        'title': title,
        'thumbnail': thumbnail})
    print(g.head(n=4))

# %%
#videoo = ['JoH-PBzb4ks', 'XM3q5l4bhL4', 'rmDzaw-FOHM', 'soOX-09dsCw', 'Rh7vXE8RfVg','1L_7BjENV48','qOid6KJa7aE','jDhKvYxvklw','02g_5V9zPug'] #test run
videoo = resultList
video = videoo
    
vid_ID = []
title = []
thumbnail = []
try:
    for v in video:
        vid_url = "https://www.youtube.com/watch?v=%s" % v
        vid = pafy.new(vid_url)
        title.append(vid.title)
        thumbnail.append(vid.thumb)
        vid_ID.append(v)
except Exception:
    pass
  
t = pd.DataFrame(
    {
    'vID': vid_ID,
    'title': title,
    'thumbnail': thumbnail})

# %%
t.head(n=3)
# Out:
# 22   Renault 5 Turbo [ Turbo 2 - GT Turbo - Copa Tu...  fNQ-Uq33l5I  055rn5
# 23   Renault 5 Turbo [ Turbo 2 - GT Turbo - Copa Tu...  fNQ-Uq33l5I  023qc5
# 24                【GT5】【DEMO】 ルノー 5 Maxi ターボ ラリーカー '85  w5wKz42VzQQ  02w37j
# 25                【GT5】【DEMO】 ルノー 5 Maxi ターボ ラリーカー '85  w5wKz42VzQQ  055rn5
# 26                【GT5】【DEMO】 ルノー 5 Maxi ターボ ラリーカー '85  w5wKz42VzQQ  023qc5
# 27         Renault 5 Klub Polska - Miedziana Góra 2008  JWlJn3nz-lI  02w37j
# 28         Renault 5 Klub Polska - Miedziana Góra 2008  JWlJn3nz-lI  055rn5
# 29         Renault 5 Klub Polska - Miedziana Góra 2008  JWlJn3nz-lI  023qc5
# ..                                                 ...          ...     ...
# 132              Vidéo embarqué R5 Turbo Tour de Corse  CeVBInQZKmE  02w37j
# 133              Vidéo embarqué R5 Turbo Tour de Corse  CeVBInQZKmE  055rn5
# 134              Vidéo embarqué R5 Turbo Tour de Corse  CeVBInQZKmE  023qc5
# 135                                   r5 gte 1.7.turbo  zfOi_lO3TZE  02w37j
# 136                                   r5 gte 1.7.turbo  zfOi_lO3TZE  055rn5
# 137                                   r5 gte 1.7.turbo  zfOi_lO3TZE  023qc5
# 138  RBR MALAGA A7000 v1.03 By Liquido (R5 Maxi Turbo)  _Xturh812c0  02w37j
# 139  RBR MALAGA A7000 v1.03 By Liquido (R5 Maxi Turbo)  _Xturh812c0  055rn5
# 140  RBR MALAGA A7000 v1.03 By Liquido (R5 Maxi Turbo)  _Xturh812c0  023qc5
# 141    Club Renault 5 México. Teotihuacan-México 2012.  6Jvi0HiS0Zo  02w37j
# 142    Club Renault 5 México. Teotihuacan-México 2012.  6Jvi0HiS0Zo  055rn5
# 143    Club Renault 5 México. Teotihuacan-México 2012.  6Jvi0HiS0Zo  023qc5
# 144                       renault 5 maxi turbo tribute  4apoEgiRsyM  02w37j
# 145                       renault 5 maxi turbo tribute  4apoEgiRsyM  055rn5
# 146                       renault 5 maxi turbo tribute  4apoEgiRsyM  023qc5
# 147                             renault 5 gt turbo evo  _szU_pVpn8g  02w37j
# 148                             renault 5 gt turbo evo  _szU_pVpn8g  055rn5
# 149                             renault 5 gt turbo evo  _szU_pVpn8g  023qc5
# 150                            renault 5 maxiturbo WRC  hDNzhpVTQhE  02w37j
# 151                            renault 5 maxiturbo WRC  hDNzhpVTQhE  055rn5
# 152                            renault 5 maxiturbo WRC  hDNzhpVTQhE  023qc5
# 153  ef-racing renault 5 gt turbo prove mappatura p...  c0vsBgxI3-c  02w37j
# 154  ef-racing renault 5 gt turbo prove mappatura p...  c0vsBgxI3-c  055rn5
# 155  ef-racing renault 5 gt turbo prove mappatura p...  c0vsBgxI3-c  023qc5
# 156  WRC 3 // Renault 5 GT Turbo - Rally de México ...  uGK2nfa0P5A  02w37j
# 157  WRC 3 // Renault 5 GT Turbo - Rally de México ...  uGK2nfa0P5A  055rn5
# 158  WRC 3 // Renault 5 GT Turbo - Rally de México ...  uGK2nfa0P5A  023qc5
# 159  World Series by Renault 2014 : Jean Ragnotti’s...  aQcrORtphGE  02w37j
# 160  World Series by Renault 2014 : Jean Ragnotti’s...  aQcrORtphGE  055rn5
# 161  World Series by Renault 2014 : Jean Ragnotti’s...  aQcrORtphGE  023qc5
#
# [162 rows x 4 columns]
